# %%
import numpy as np
from simsopt.geo import CurveCWSFourier, SurfaceRZFourier
import matplotlib.pyplot as plt

# %%
wout = '/home/joaobiu/simsopt_curvecws/tests/test_files/input.LandremanPaul2021_QA'

# %%
s = SurfaceRZFourier.from_vmec_input(wout, range="half period", ntheta=32, nphi=32)
cws = SurfaceRZFourier.from_vmec_input(wout, range="half period", ntheta=32, nphi=32)
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
s.plot(ax = ax, show=False, alpha=0.9)
cws.extend_via_normal(0.2)
cws.plot(ax = ax, show=True, alpha=0.3, color="g")
# Out:
# <Axes3DSubplot: >

# %%
cws = s.extend_via_normal(0.15)
s.plot()
# Out:
# <Axes3DSubplot: >
